# %%
import pandas as pd

data = {
    "Date": [
        "2024-01-01","2024-01-02","2024-01-03","2024-01-04","2024-01-05",
        "2024-01-06","2024-01-07","2024-01-08","2024-01-09","2024-01-10"
    ],
    "Sales": [200,150,300,250,400,180,220,350,270,320],
    "Category": [
        "Technology","Furniture","Technology","Office Supplies","Technology",
        "Furniture","Office Supplies","Technology","Furniture","Technology"
    ],
    "Region": [
        "West","East","West","South","North",
        "West","East","South","North","West"
    ]
}

df = pd.DataFrame(data)

df.to_csv("sales_data.csv", index=False)

df.head()
# Out:
#          Date  Sales         Category Region
# 0  2024-01-01    200       Technology   West
# 1  2024-01-02    150        Furniture   East
# 2  2024-01-03    300       Technology   West
# 3  2024-01-04    250  Office Supplies  South
# 4  2024-01-05    400       Technology  North
